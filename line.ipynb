# %% [markdown]
# # Matplotlib Line.
# Date : 21, Jan, 2024

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %% [markdown]
# Linestyle : We can use the keyword argument linestyle, or shorter ls, to change the style of the plotted line

# %% [markdown]
# Example : Use a dotted line:

# %%
ypoint=np.array([3, 8, 1, 10])

plt.plot(ypoint, linestyle='dotted')
plt.show()

# %% [markdown]
# Shorter Syntax : The line style can be written in a shorter syntax
#
# linestyle can be written as 'ls'
#
# dotted can be written as ':'
#
# dashed can be written as '--'
#
# dashdot can be written as '-.'
#
# None can be written as ''

# %% [markdown]
# Line Color : We can use the keyword argument color or the shorter c to set the color of the line.

# %% [markdown]
# Example : Set the line color to red:

# %%
ypoint=np.array([3, 8, 1, 10])

plt.plot(ypoint, color='r')
plt.show()

# %% [markdown]
# Line Width : We can use the keyword argument linewidth or the shorter lw to change the width of the line.
#
# The value is a floating number, in points.

# %% [markdown]
# Example : Plot with a 20.5pt wide line.

# %%
ypoint=np.array([3, 8, 1, 10])

plt.plot(ypoint, linewidth='20.5')
plt.show()

# %% [markdown]
# Multiple Lines : We can plot as many lines as you like by simply adding more plt.plot() functions.

# %% [markdown]
# Example : Draw two lines by specifying a plt.plot() function for each line.

# %%
y1=np.array([3, 8, 1, 10])
y2=np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %% [markdown]
# We can also plot many lines by adding the points for the x- and y-axis for each line in the same plt.plot() function.
#
# (In the examples above we only specified the points on the y-axis, meaning that the points on the x-axis got the the default values (0, 1, 2, 3).)
#
# The x- and y- values come in pairs.
